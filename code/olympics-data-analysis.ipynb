# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/120-years-of-olympic-history-athletes-and-results/noc_regions.csv
# /kaggle/input/120-years-of-olympic-history-athletes-and-results/athlete_events.csv

# %%
df= pd.read_csv('/kaggle/input/120-years-of-olympic-history-athletes-and-results/athlete_events.csv')
region_df= pd.read_csv('/kaggle/input/120-years-of-olympic-history-athletes-and-results/noc_regions.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    269731
# True       1385
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df[df.duplicated()]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1252       704                   Dsir Antoine Acket   M  27.0     NaN     NaN
# 4282      2449               William Truman Aldrich   M  48.0     NaN     NaN
# 4283      2449               William Truman Aldrich   M  48.0     NaN     NaN
# 4862      2777               Hermann Reinhard Alker   M  43.0     NaN     NaN
# 4864      2777               Hermann Reinhard Alker   M  43.0     NaN     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 269994  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269995  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269997  135072  Anna Katrina Zinkeisen (-Heseltine)   F  46.0     NaN     NaN
# 269999  135073   Doris Clare Zinkeisen (-Johnstone)   F  49.0     NaN     NaN
# 270200  135173                     Henri Achille Zo   M  58.0     NaN     NaN
#
# ...

# %%
df[df['Name']== 'Usain Bolt']
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
df['Sport'].value_counts()
# Out:
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10859
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: Sport, Length: 66, dtype: int64

# %%
df['Medal'].value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
groups= df.groupby(['Name','Medal'])

# %%
groups['Name','Medal'].count()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                      Name  Medal
# Name                         Medal
# A. Albert                    Gold       1      1
# A. Dubois                    Bronze     1      1
#                              Silver     1      1
# A. Joshua "Josh" West        Silver     1      1
# A. Lawry                     Silver     1      1
# ...                                   ...    ...
# va Risztov                   Gold       1      1
# va Szkely (-Gyarmati)        Gold       1      1
#                              Silver     1      1
# ver Maximiliano David Banega Gold       1      1
# ystein Pettersen             Gold       1      1
#
# [33710 rows x 2 columns]

# %%
temp_df= df[df['Medal']=='Gold']

# %%
groups= temp_df.groupby(['Name'])

# %%
groups['Medal'].count().sort_values(ascending=False)
# Out:
# Name
# Michael Fred Phelps, II               23
# Raymond Clarence "Ray" Ewry           10
# Paavo Johannes Nurmi                   9
# Larysa Semenivna Latynina (Diriy-)     9
# Mark Andrew Spitz                      9
#                                       ..
# Hermann "Hannes" Hansen                1
# Hermann Alexandre de Pourtals          1
# Hermann Gehri                          1
# Hermann Joseph Barrelet                1
# ystein Pettersen                       1
# Name: Medal, Length: 10413, dtype: int64

# %%
#### Top5 with most golds

temp_df= df[df['Medal']=='Gold']
groups= temp_df.groupby(['Name'])
groups['Medal'].count().sort_values(ascending=False)
# Out:
# Name
# Michael Fred Phelps, II               23
# Raymond Clarence "Ray" Ewry           10
# Paavo Johannes Nurmi                   9
# Larysa Semenivna Latynina (Diriy-)     9
# Mark Andrew Spitz                      9
#                                       ..
# Hermann "Hannes" Hansen                1
# Hermann Alexandre de Pourtals          1
# Hermann Gehri                          1
# Hermann Joseph Barrelet                1
# ystein Pettersen                       1
# Name: Medal, Length: 10413, dtype: int64

# %%
df= df[df['Season']=='Summer']

# %%
#### Top5 countries with most golds

temp_df= df[df['Medal']=='Gold']
groups= temp_df.groupby(['NOC'])
groups['Medal'].count().sort_values(ascending=False)
# Out:
# NOC
# USA    2472
# URS     832
# GBR     636
# GER     592
# ITA     518
#        ...
# SGP       1
# MOZ       1
# PUR       1
# PAN       1
# JOR       1
# Name: Medal, Length: 107, dtype: int64

# %%
#### Top5 countries with most medals

groups= df.groupby(['NOC'])
groups['Medal'].count().sort_values(ascending=False)
# Out:
# NOC
# USA    5002
# URS    2063
# GBR    1985
# GER    1779
# FRA    1627
#        ...
# GEQ       0
# PNG       0
# PLW       0
# PLE       0
# LBA       0
# Name: Medal, Length: 230, dtype: int64

# %%
#### Top5 countries with most golds in 2016

#temp_df= df[df['Medal']=='Gold' & df['Year']==2016]
#groups= temp_df.groupby(['NOC'])
#groups['Medal'].count().sort_values(ascending=False)

# %%
#### Top5 countries with most golds in 2016

mask1= df['Medal']=='Gold'
mask2= df['Year']== 2016
temp_df= df[mask1 & mask2]
groups= temp_df.groupby(['NOC'])
groups['Medal'].count().sort_values(ascending=False)
# Out:
# NOC
# USA    139
# GBR     64
# RUS     52
# GER     49
# CHN     46
# BRA     36
# AUS     23
# ARG     21
# FRA     20
# JPN     17
# DEN     15
# SRB     14
# FIJ     13
# KOR     13
# HUN     12
# JAM     11
# NED      9
# ESP      9
# ITA      8
# CRO      7
# SUI      6
# NZL      6
# KEN      6
# CUB      5
# UZB      4
# ROU      4
# CAN      4
# POL      3
# GRE      3
# SVK      3
# KAZ      3
# COL      3
# IRI      3
# BEL      2
# RSA      2
# GEO      2
# PRK      2
# SWE      2
# INA      2
# THA      2
# UKR      2
# TPE      1
# BAH      1
# TUR      1
# AZE      1
# TJK      1
# ETH      1
# SLO      1
# SGP      1
# PUR      1
# CZE      1
# BLR      1
# KOS      1
# BRN      1
# JOR      1
# CIV      1
# ARM      1
# IOA      1
# VIE      1
# Name: Medal, dtype: int64

# %%
mask1= df['Medal']=='Gold'
mask2= df['Year']== 2016
temp_df= df[mask1 & mask2]

temp_df.duplicated()
# Out:
# 1080      False
# 1495      False
# 1849      False
# 1850      False
# 2453      False
#           ...
# 269277    False
# 269312    False
# 269368    False
# 269511    False
# 270281    False
# Length: 665, dtype: bool

# %%
df.sample(5)
# Out:
#             ID                            Name Sex   Age  Height  Weight  \
# 238115  119411      Sergey Yuryevich Tetyukhin   M  36.0   197.0    89.0
# 93626    47399  Albert Helgerud (Thorvaldsen-)   M  35.0     NaN     NaN
# 223230  112115                    Pierre Smets   M  22.0   193.0   109.0
# 218502  109744               Zohar Hen Shikler   F  19.0   178.0    61.0
# 181950   91448                 Park Byeong-Hyo   M  21.0   166.0    62.0
#
#                Team  NOC        Games  Year  Season            City  \
# 238115       Russia  RUS  2012 Summer  2012  Summer          London
# 93626        Norway  NOR  1912 Summer  1912  Summer       Stockholm
# 223230      Belgium  BEL  1972 Summer  1972  Summer          Munich
# 218502       Israel  ISR  2016 Summer  2016  Summer  Rio de Janeiro
# 181950  South Korea  KOR  1984 Summer  1984  Summer     Los Angeles
#
#              Sport                                              Event Medal
# ...

# %%
groups= temp_df.groupby(['Sport','Event','Medal'])

# %%
groups.count()
# Out:
#                                                                 ID  Name  Sex  \
# Sport     Event                                          Medal
# Archery   Archery Men's Individual                       Gold    1     1    1
#           Archery Men's Team                             Gold    3     3    3
#           Archery Women's Individual                     Gold    1     1    1
#           Archery Women's Team                           Gold    3     3    3
# Athletics Athletics Men's 1,500 metres                   Gold    1     1    1
# ...                                                             ..   ...  ...
# Wrestling Wrestling Women's Flyweight, Freestyle         Gold    1     1    1
#           Wrestling Women's Heavyweight, Freestyle       Gold    1     1    1
#           Wrestling Women's Light-Heavyweight, Freestyle Gold    1     1    1
#           Wrestling Women's Lightweight, Freestyle       Gold    1     1    1
# ...

# %%
groups= df.groupby(['Sport','Event','NOC','Year','Team'])
events_DF= groups['Medal'].count().reset_index()

# %%
events_DF
# Out:
#              Sport                                      Event  NOC  Year  \
# 0      Aeronautics              Aeronautics Mixed Aeronautics  SUI  1936
# 1         Alpinism                    Alpinism Mixed Alpinism  GER  1932
# 2         Alpinism                    Alpinism Mixed Alpinism  SUI  1936
# 3          Archery       Archery Men's Au Chapelet, 33 metres  BEL  1900
# 4          Archery       Archery Men's Au Chapelet, 33 metres  FRA  1900
# ...            ...                                        ...  ...   ...
# 98889    Wrestling  Wrestling Women's Middleweight, Freestyle  UKR  2016
# 98890    Wrestling  Wrestling Women's Middleweight, Freestyle  USA  2004
# 98891    Wrestling  Wrestling Women's Middleweight, Freestyle  USA  2008
# 98892    Wrestling  Wrestling Women's Middleweight, Freestyle  USA  2012
# 98893    Wrestling  Wrestling Women's Middleweight, Freestyle  USA  2016
#
#                 Team  Medal
# 0        Switzerland      1
# 1            Germany      2
# ...

# %%
#### Top5 countries with most golds

temp_df= events_DF[events_DF['Medal']==1]
groups= temp_df.groupby(['NOC'])
groups['Medal'].count().sort_values(ascending=False)
# Out:
# NOC
# USA    902
# URS    501
# GER    418
# GBR    415
# FRA    394
#       ...
# KOS      1
# AHO      1
# JOR      1
# IRQ      1
# ERI      1
# Name: Medal, Length: 144, dtype: int64

# %%
events_DF.sample(6)
# Out:
#            Sport                                     Event  NOC  Year  \
# 79330   Swimming    Swimming Women's 100 metres Backstroke  VNM  1968
# 25595     Boxing                Boxing Men's Featherweight  IND  1976
# 94447  Wrestling  Wrestling Men's Heavyweight, Greco-Roman  BLR  2004
# 65587   Shooting       Shooting Men's Air Rifle, 10 metres  NOR  2016
# 10113  Athletics                Athletics Men's 800 metres  GER  1896
# 34567    Cycling     Cycling Men's 1,000 metres Time Trial  NED  1996
#
#                 Team  Medal
# 79330  South Vietnam      0
# 25595          India      0
# 94447        Belarus      0
# 65587         Norway      0
# 10113        Germany      0
# 34567    Netherlands      0

# %%
groups= df.groupby(['Sport','Event','NOC','Year','Medal','Team'])
events_DF= groups['Season'].count().reset_index()

# %%
events_DF
# Out:
#              Sport                                      Event  NOC  Year  \
# 0      Aeronautics              Aeronautics Mixed Aeronautics  SUI  1936
# 1         Alpinism                    Alpinism Mixed Alpinism  GER  1932
# 2         Alpinism                    Alpinism Mixed Alpinism  SUI  1936
# 3          Archery       Archery Men's Au Chapelet, 33 metres  BEL  1900
# 4          Archery       Archery Men's Au Chapelet, 33 metres  FRA  1900
# ...            ...                                        ...  ...   ...
# 16069    Wrestling  Wrestling Women's Middleweight, Freestyle  POL  2016
# 16070    Wrestling  Wrestling Women's Middleweight, Freestyle  RUS  2008
# 16071    Wrestling  Wrestling Women's Middleweight, Freestyle  RUS  2012
# 16072    Wrestling  Wrestling Women's Middleweight, Freestyle  USA  2004
# 16073    Wrestling  Wrestling Women's Middleweight, Freestyle  USA  2008
#
#         Medal           Team  Season
# 0        Gold    Switzerland       1
# ...

# %%
#### Top5 countries with most golds

events_DF.drop_duplicates(['Medal','Event'])
temp_df= events_DF[events_DF['Medal']=='Gold']
groups= temp_df.groupby(['NOC'])
groups['Medal'].count().sort_values(ascending=False).head(10)
# Out:
# NOC
# USA    1035
# URS     394
# GBR     278
# GER     235
# FRA     234
# CHN     227
# ITA     219
# HUN     178
# RUS     153
# GDR     153
# Name: Medal, dtype: int64

# %%
tempo_DF= events_DF.drop_duplicates(['Medal','Event'])
tempo_DF[tempo_DF['Team']=='India']
# Out:
#          Sport                               Event  NOC  Year   Medal   Team  \
# 828  Athletics  Athletics Men's 200 metres Hurdles  IND  1900  Silver  India
#
#      Season
# 828       1

# %%
mask1= df['Team']=='India'
mask2= df['Medal']=='Gold'
df[mask1 & mask2]
# Out:
#             ID                    Name Sex   Age  Height  Weight   Team  NOC  \
# 4732      2699             Shaukat Ali   M  30.0     NaN     NaN  India  IND
# 4736      2703        Syed Mushtaq Ali   M  22.0   165.0    61.0  India  IND
# 5032      2864     Richard James Allen   M  25.0   172.0     NaN  India  IND
# 5033      2864     Richard James Allen   M  30.0   172.0     NaN  India  IND
# 5034      2864     Richard James Allen   M  34.0   172.0     NaN  India  IND
# ...        ...                     ...  ..   ...     ...     ...    ...  ...
# 233749  117232      Dung Dung Sylvanus   M  31.0   160.0    62.0  India  IND
# 236445  118553  Carlyle Carrol Tapsell   M  23.0   182.0     NaN  India  IND
# 236446  118553  Carlyle Carrol Tapsell   M  27.0   182.0     NaN  India  IND
# 250689  125560         Max "Maxie" Vaz   M   NaN     NaN     NaN  India  IND
# 266934  133554    Sayed Muhammad Yusuf   M   NaN     NaN     NaN  India  IND
#
# ...

# %%
df.head()
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#               Team  NOC        Games  Year  Season         City       Sport  \
# 0            China  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1            China  CHN  2012 Summer  2012  Summer       London        Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 26     Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                            Event Medal
# 0    Basketball Men's Basketball   NaN
# ...

# %%
df.shape
# Out:
# (222552, 15)

# %%
df= df[df['Season']=='Summer']

# %%
region_df.sample()
# Out:
#     NOC region notes
# 60  EGY  Egypt   NaN

# %%
region_df.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df= df.merge(region_df,on='NOC',how='left')

# %%
df['region'].unique()
# Out:
# array(['China', 'Denmark', 'Netherlands', 'Finland', 'Norway', 'Romania',
#        'Estonia', 'France', 'Morocco', 'Spain', 'Egypt', 'Iran',
#        'Bulgaria', 'Italy', 'Chad', 'Azerbaijan', 'Sudan', 'Russia',
#        'Argentina', 'Cuba', 'Belarus', 'Greece', 'Cameroon', 'Turkey',
#        'Chile', 'Mexico', 'USA', 'Nicaragua', 'Hungary', 'Nigeria',
#        'Algeria', 'Kuwait', 'Bahrain', 'Pakistan', 'Iraq', 'Syria',
#        'Lebanon', 'Qatar', 'Malaysia', 'Germany', 'Canada', 'Ireland',
#        'Australia', 'South Africa', 'Eritrea', 'Tanzania', 'Jordan',
#        'Tunisia', 'Libya', 'Belgium', 'Djibouti', 'Palestine', 'Comoros',
#        'Kazakhstan', 'Brunei', 'India', 'Saudi Arabia', 'Maldives',
#        'Ethiopia', 'United Arab Emirates', 'Yemen', 'Indonesia',
#        'Philippines', nan, 'Uzbekistan', 'Kyrgyzstan', 'Tajikistan',
#        'Japan', 'Republic of Congo', 'Switzerland', 'Brazil', 'Monaco',
#        'Israel', 'Uruguay', 'Sweden', 'Sri Lanka', 'Armenia',
# ...

# %%
df['region'].unique().shape
# Out:
# (206,)

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9189
# Height     51857
# Weight     53854
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     188464
# region       370
# notes     218151
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1385

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Medal'].value_counts()
# Out:
# Gold      11456
# Bronze    11409
# Silver    11212
# Name: Medal, dtype: int64

# %%
pd.get_dummies(df['Medal'])

## https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html
# Out:
#         Bronze  Gold  Silver
# 0            0     0       0
# 1            0     0       0
# 2            0     0       0
# 3            0     1       0
# 4            0     0       0
# ...        ...   ...     ...
# 222547       0     0       0
# 222548       0     0       0
# 222549       0     0       0
# 222550       0     0       0
# 222551       0     0       0
#
# [221167 rows x 3 columns]

# %%
temp_df= pd.get_dummies(df['Medal'])

# %%
pd.concat([df,temp_df],axis=1)
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 222547  135565            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 222548  135566          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 222549  135567        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 222550  135567        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 222551  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
df= pd.concat([df,temp_df],axis=1)

# %%
groups= df.groupby('NOC')

# %%
groups.sum()
# Out:
#             ID      Age    Height    Weight     Year  Bronze   Gold  Silver
# NOC
# AFG    8918075   1836.0    9212.0    4020.0   247720     2.0    0.0     0.0
# AHO    4345762   1916.0    8862.0    3803.0   146544     0.0    0.0     1.0
# ALB    4583008   1631.0    8635.0    3879.0   126092     0.0    0.0     0.0
# ALG   26774400  13035.0   84571.0   33338.0  1076852     8.0    5.0     4.0
# AND    3328267   1448.0    8131.0    3210.0   105912     0.0    0.0     0.0
# ..         ...      ...       ...       ...      ...     ...    ...     ...
# YEM     932821    675.0    4199.0    1492.0    64092     0.0    0.0     0.0
# YMD     345630    118.0     350.0     190.0     9940     0.0    0.0     0.0
# YUG  146095387  48245.0  243501.0  102379.0  4005080    92.0  130.0   161.0
# ZAM   12125915   3613.0   22122.0    9179.0   363520     1.0    0.0     1.0
# ZIM   20440062   7747.0   49565.0   19536.0   614824     1.0   17.0     4.0
#
# [230 rows x 8 columns]

# %%
groups.sum()[['Gold','Silver','Bronze']]
# Out:
#       Gold  Silver  Bronze
# NOC
# AFG    0.0     0.0     2.0
# AHO    0.0     1.0     0.0
# ALB    0.0     0.0     0.0
# ALG    5.0     4.0     8.0
# AND    0.0     0.0     0.0
# ..     ...     ...     ...
# YEM    0.0     0.0     0.0
# YMD    0.0     0.0     0.0
# YUG  130.0   161.0    92.0
# ZAM    0.0     1.0     1.0
# ZIM   17.0     4.0     1.0
#
# [230 rows x 3 columns]

# %%
groups.sum()[['Gold','Silver','Bronze']].sort_values('Gold',ascending=False)

## a team event or game, the whole team (11-15 players) win the medal instead of just 1. 
## that is why US has so many medals
## so we have to correct it
# Out:
#        Gold  Silver  Bronze
# NOC
# USA  2472.0  1333.0  1197.0
# URS   832.0   635.0   596.0
# GBR   635.0   729.0   620.0
# GER   592.0   538.0   649.0
# ITA   518.0   474.0   454.0
# ..      ...     ...     ...
# AHO     0.0     1.0     0.0
# LBR     0.0     0.0     0.0
# LCA     0.0     0.0     0.0
# LES     0.0     0.0     0.0
# LBA     0.0     0.0     0.0
#
# [230 rows x 3 columns]

# %%
groups.sum()[['Gold','Silver','Bronze']].sort_values('Gold',ascending=False).reset_index()
# Out:
#      NOC    Gold  Silver  Bronze
# 0    USA  2472.0  1333.0  1197.0
# 1    URS   832.0   635.0   596.0
# 2    GBR   635.0   729.0   620.0
# 3    GER   592.0   538.0   649.0
# 4    ITA   518.0   474.0   454.0
# ..   ...     ...     ...     ...
# 225  AHO     0.0     1.0     0.0
# 226  LBR     0.0     0.0     0.0
# 227  LCA     0.0     0.0     0.0
# 228  LES     0.0     0.0     0.0
# 229  LBA     0.0     0.0     0.0
#
# [230 rows x 4 columns]

# %%
medal_tally= df.drop_duplicates(subset=['Team','NOC','Games','Year','City','Sport','Event','Medal'])

# %%
medal_tally.head()
# Out:
#    ID                                Name Sex   Age  Height  Weight  \
# 0   1                           A Dijiang   M  24.0   180.0    80.0
# 1   2                            A Lamusi   M  23.0   170.0    60.0
# 2   3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3   4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#              Team  NOC        Games  Year  Season         City       Sport  \
# 0           China  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1           China  CHN  2012 Summer  2012  Summer       London        Judo
# 2         Denmark  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3  Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 4     Netherlands  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                           Event Medal       region notes  Bronze  Gold  Silver
# ...

# %%
groups= medal_tally.groupby('NOC')

# %%
groups.sum()[['Gold','Silver','Bronze']]
# Out:
#      Gold  Silver  Bronze
# NOC
# AFG   0.0     0.0     2.0
# AHO   0.0     1.0     0.0
# ALB   0.0     0.0     0.0
# ALG   5.0     4.0     8.0
# AND   0.0     0.0     0.0
# ..    ...     ...     ...
# YEM   0.0     0.0     0.0
# YMD   0.0     0.0     0.0
# YUG  26.0    29.0    28.0
# ZAM   0.0     1.0     1.0
# ZIM   3.0     4.0     1.0
#
# [230 rows x 3 columns]

# %%
groups.sum()[['Gold','Silver','Bronze']].sort_values('Gold',ascending=False).reset_index()
# Out:
#      NOC    Gold  Silver  Bronze
# 0    USA  1035.0   802.0   708.0
# 1    URS   394.0   317.0   294.0
# 2    GBR   278.0   317.0   300.0
# 3    GER   235.0   261.0   283.0
# 4    FRA   234.0   256.0   287.0
# ..   ...     ...     ...     ...
# 225  AHO     0.0     1.0     0.0
# 226  LBR     0.0     0.0     0.0
# 227  LCA     0.0     0.0     0.0
# 228  LES     0.0     0.0     0.0
# 229  LBA     0.0     0.0     0.0
#
# [230 rows x 4 columns]

# %%
medal_tally= groups.sum()[['Gold','Silver','Bronze']].sort_values('Gold',ascending=False).reset_index()

# %%
medal_tally
# Out:
#      NOC    Gold  Silver  Bronze
# 0    USA  1035.0   802.0   708.0
# 1    URS   394.0   317.0   294.0
# 2    GBR   278.0   317.0   300.0
# 3    GER   235.0   261.0   283.0
# 4    FRA   234.0   256.0   287.0
# ..   ...     ...     ...     ...
# 225  AHO     0.0     1.0     0.0
# 226  LBR     0.0     0.0     0.0
# 227  LCA     0.0     0.0     0.0
# 228  LES     0.0     0.0     0.0
# 229  LBA     0.0     0.0     0.0
#
# [230 rows x 4 columns]

# %%
medal_tally[medal_tally['NOC']=='IND']
# Out:
#     NOC  Gold  Silver  Bronze
# 53  IND   9.0     7.0    12.0
